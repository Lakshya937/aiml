# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshya937/aiml/blob/main/EXPERIMENT5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
url = 'https://raw.githubusercontent.com/Lakshya937/aiml/main/All%20Ended%20Netflix%20Original%20Shows.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#                                             Title                      Genre  \
# 0                                  House of Cards            Political drama
# 1                         Orange Is the New Black               Comedy drama
# 2                                      Marco Polo           Historical drama
# 3                                       Bloodline                   Thriller
# 4                                       Daredevil       Superherolegal drama
# ...                                           ...                        ...
# 1348  Mystery Science Theater 3000(seasons 11–12)      Comic science fiction
# 1349                            Slasher(season 2)     Horroranthology series
# 1350                      EastSiders(seasons 3–4)               Black comedy
# 1351                    The Mafia Dolls(season 2)                 Telenovela
# 1352                         Lucifer(seasons 4–6)  Fantasy/police procedural
#
# ...

# %%
iris = load_iris()
X = iris.data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)  # Set the number of components to reduce to
X_pca = pca.fit_transform(X_scaled)  # Fit and transform the data

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=iris.target, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Iris Dataset')
plt.colorbar(label='Target Class')
plt.show()

# %%
explained_variance = pca.explained_variance_ratio_
print(f"Explained Variance of PC1: {explained_variance[0]:.2f}")
print(f"Explained Variance of PC2: {explained_variance[1]:.2f}")
# Out:
# Explained Variance of PC1: 0.73
# Explained Variance of PC2: 0.23
